# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_silver_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_silver_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_silver_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_bronze_sd_add

# %%
# %sql
select * from workspace.damg7370.demo_cust_silver_sd_add
