# %%
# %sql
select * from damg7370.demo_cust_bronze_sd

# %%
# %sql
select * from damg7370.demo_cust_silver_sd

# %%
# %sql
select * from damg7370.demo_cust_bronze_sd

# %%
# %sql
select * from damg7370.demo_cust_silver_sd

# %%
# %sql
select * from damg7370.demo_cust_bronze_sd

# %%
# %sql
select * from damg7370.demo_cust_silver_sd

# %%
# %sql
select * from damg7370.demo_cust_bronze_sd

# %%
# %sql
select * from damg7370.demo_cust_silver_sd
